# %%
import pandas as pd

# %%
import pytest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pytest
#
# ModuleNotFoundError: No module named 'pytest'
